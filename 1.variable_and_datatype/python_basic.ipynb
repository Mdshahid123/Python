# %% [markdown]
# ## creating variable

# %% [markdown]
# ### int data type

# %%
a=5  #integer
print(a)
# Out:
# 5

# %%
b=19 #integer
print(b)
# Out:
# 19

# %%
c=45 # integer
print(c)
# Out:
# 45

# %% [markdown]
# ### float data type

# %%
a=4.5 #float
print(a)
# Out:
# 4.5

# %%
b=7.8 #float
print(b)
# Out:
# 7.8

# %% [markdown]
# ### string data type

# %%
name="shahid" #string
print(name)
# Out:
# shahid

# %%
city="new delhi"  #string
print("city")
# Out:
# city

# %% [markdown]
# ### boolean data type

# %%
a=True # boolean
b=False # boolean
print(a,b)
# Out:
# True False

# %%
print("hello")
# Out:
# hello

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### type checking

# %%
name="shahid"
type(name)
# Out:
# str

# %%
a=35
type(a)
# Out:
# int

# %% [markdown]
# ### type casting

# %%
a="45"
b=""
# Out:
# 45
# 45

# %% [markdown]
# ### string formating
