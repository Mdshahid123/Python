# %% [markdown]
# ## conditinal statment
#
#
# ### conditional statement is used to perform a task on the basis of condition
#
# #### we have follwing types of condtional statement
#
# #### if statement
# #### if else statment
# #### if elif statement

# %%
# if statement

# sytax 
# if condtion:
    # code or task


age = 18

if age >= 18:
    print("You can vote")

# %%
# if else statement
age=int(input("enter your age:"))
if age >= 18:
  print("you are egligible for vote")
else:
  print("you are not egligible for vote")
# Out:
# you are not egligible for vote

# %%
# if we have to perform the task on the basis of mutiple condtion then we use 
# if elif 

# if elif stament
money=10
if money==10:
 print("i will buy chockobar")
elif money==20:
 print("i will buy vanilla")
elif money==100:
 print("i will buy cone")
else:
 print("i will buy noting")

# %%
# wap to display the grade  obtain by the student 
# take marks as a input from the user 

marks=int(input("enter your percentage in your 12th class"))
if marks >=50 and marks<=60:
  print("Grade D")
elif marks>=60 and  marks<=70:
  print("Your grade is C")
elif marks>=70 and  marks<=80:
 print("your grade is B")
elif marks>=80 and  marks<=90:
 print("your grade is A")
elif marks>=90 and  marks<=100:
 print("your grade is O")
else:
 print("sorry you are fail do work hard")
# Out:
# sorry you are fail do work hard

# %%
# wap to display wheather the student is egligible for data anlyst job or not 

degree=input("enter your degree in Capital latter:")
if(degree=="MBA" or degree=="BTECH" or degree=="BCOM" or degree=="BA" or degree=="BSC"  or degree=="BCA"):
  print("you are eglgible for data analyst job")

else:
  print("you are not egligible for data anlyst job")
# Out:
# you are not egligible for data anlyst job
