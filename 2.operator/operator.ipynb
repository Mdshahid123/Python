# %% [markdown]
# # CHAPTER-02  OPERATOR

# %% [markdown]
# # 1) ARITHMETIC  OPERATOR
# ### . Addition(+)<br>
# ### . Subtraction(-)<br>
# ### . Multiplication(*)<br>
# ### . Division(always float)(/)<br>
# ### . Floor Division(//)<br>
# ### . Modulus(%) (Remainder)<br>
# ### . Exponent(**)<br>

# %% [markdown]
#  # a) addition operator(+)

# %%
 
#adding integer  number
a=5
b=9
c=a+b
print(c)

# %%
# adding float number
a=9.4
b=7.8
c=a+b
print(c)

# %%
#adding complex number
a=6+3j
b=8+4J
c=a+b
print(c)

# %%
#when we add two string then it will be concatenate
a="hello"
b="shahid"
c=a+b
print(c)

# %%
# adding string with number
a="shahid"
b=5
print(a+b)

# %% [markdown]
# # b) subtraction operator(-)

# %%
#subtracting intger number
a=5
b=8
c=a-b
print(c)

# %%
#subtracting floating number
a=9.7
b=8
c=a-b
print(c)

# %%
#subtracting two string is invalid 
first_name="md"
second_name="shahid"
print(first_name-second_name)

# %%
# subtracting nmber from the string 
name="shahid"
age=24
print(name-age)

# %%
#subtracting two complex number
a=1+6J
b=9+8j
c=a-b
print(c)

# %% [markdown]
# # c) multiplication operator (*)

# %%
#multiplying two integr number
print(4*5)

# %%
#multiplying two float number
print(3.4*5.6)

# %%
# multiplying two string is invalid
print("md"*"shahid")

# %%
#multiplying string with number is valid
print("hello"*5)

# %%
#multiplying two complex number
print((3+4j)*(5+6j))

# %% [markdown]
# ## 3) Dvision operator

# %% [markdown]
# ### i) noraml division operator (/)
# #### Always gives a float (decimal number) result.
# #### Even if both numbers divide perfectly.

# %%
#dividing two integer
print(12/3)
print(5/6)

# %%
#dividing two float number
print(4.6/5.7)

# %%
#dividing two complex number
print(3+5j/5+6j)

# %%
#dividing two string invalid
print("shahid"/"md")

# %%
# dividing string with number
print("shahid"/5)

# %% [markdown]
# ## 4) modulr operator (%)
# #### It devides the  number and then return the remainder

# %%
print(25%5)

# %%
print(24%5)

# %%
print(8.4%7.4) # we will be discuss

# %% [markdown]
# ## 5) Floor Division operator (//)
#
# #### result is integer if both  number is integer (Divides and then removes the decimal part (rounds down to the nearest whole number))
#
# #### Result is an integer.0 if both is  float or if any input is float

# %%
print(25//4)

# %%
print(25.56//4.78)

print(25.67//24)

# %%
print(4.7//3)

# %%
print((3+4j)//(4+6j)) # we can'tdevid the two complex number using floor division operator

# %%
print((3+4j)//5)

# %% [markdown]
# # g) exponent operator(*)
# #### it is used to find the power of any number

# %%
print(3**3)

# %% [markdown]
# ## 2) Assinment Operator(=)
#
# ### Assignment operators are used to assign values to variables:
# ### varibale should be left side and values should be right side of a assignment operator
# ### if there is a expresstion in right side then it will be first evaluate then assign

# %%
# assignment operatos with direct values 

a=20
print(a)

# %%
# assignment operatos with expresstion 

a=30*5+5  # this is a expression which will be first evaluate then assign in to the variable
print(a)

# %%
x=5
# x = x + 3 
x+=3  # x=x+3
print(x)
# Out:
# 8

# %%
x=7
x-=8  # x=x-8
print(x)
# Out:
# -1

# %%
x=2
y=2
x = x ** 3
y**=3 #y=y**3
print(x)
print(y)
# Out:
# 8
# 8

# %%
x=9
y=9
x = x / 3
y/=3  #y=y/3
print(x)
print(y)
# Out:
# 3.0
# 3.0

# %% [markdown]
# ### Comparision operators
#
# #### Comparison operators are used to compare two values
#
# #### it return the boolean values after comparision
#
# #### follwoing are the comarision operators
#
# #### == equal operator 	(it first comare the data type and then it check the values )
# #### !=	 not equal operator
# #### >	Greater than operator
# #### <	Less than	 operator
# #### >=	Greater than or equal to	operator
# #### <=	Less than or equal to	  operator

# %%
# example 1

a=5
b=7
print(a==b)
# Out:
# False

# %%
# example 2

name1="ishika"
name2="srishti"
print(name1==name2)
# Out:
# False

# %%
a=5
b=5
print(a==b)
# Out:
# True

# %% [markdown]
# ## Identity operator
# #### is
# #### is not

# %%
# is identity opertor 

a=20
b=a

print(a is b)
# Out:
# True

# %%
l1=[10,"shahid","sanjay"]
l2=[10,"shahid","sanjay"]
print(l1 is l2)
print(l1==l2)
# Out:
# False
# True

# %%
l1=[30,"shahid","sanjay"]
l2=l1
print(l1 is l2)
print(l1==l2)
# Out:
# True
# True

# %%
l1="shahid"
l2="sanjay"
print(l1==l2)  # false 
print(l1 is l2 )  #false
# Out:
# False
# False

# %%
l1=[10,50,60]
t=(10,50,60)

print(l1 is t ) # false 
print(l1 == t ) #false
# Out:
# False
# False

# %% [markdown]
# ## question practice
# ## ques:What does the is operator check?
# #### if two values are equal
# #### If two variables point to the same object
# #### If a value exists

# %% [markdown]
# ## Membership Operators
# #### Membership operators are used to test if a sequence is presented in an object

# %%
fruits = ["apple", "banana", "cherry"]
name="md shahid"

print("banana" in fruits)
print("grapes" in fruits)
print("md" in name )
print("p" in  name)
# Out:
# True
# False
# True
# False

# %%
print(100 + 5 * 3)
# Out:
# 115

# %%
print(100+15-90)
print(100-90+15)
print(100-15+90)
# Out:
# 25
# 25
# 175

# %% [markdown]
# ## practcie question
# ## ques:What is the result of 2 + 3 * 4?
#
#
# #### 20
# #### 14
# ## 24

# %%
result = 10 + 5 * 2 > 15 and 20 - 4 / 2 == 18 or not (3 * 2 < 5)

print(result)
# Out:
# True
